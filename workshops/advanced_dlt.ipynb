# %% [markdown]
# # Load data from an API

# %%
pip install "dlt[duckdb]"
# Out:
# Collecting dlt[duckdb]
#   Downloading dlt-0.4.3-py3-none-any.whl (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.2/540.2 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (2.0.25)
# Requirement already satisfied: astunparse>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (1.6.3)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (8.1.7)
# Requirement already satisfied: fsspec>=2022.4.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (2023.6.0)
# Collecting gitpython>=3.1.29 (from dlt[duckdb])
#   Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 7.3 MB/s eta 0:00:00
# Collecting giturlparse>=0.10.0 (from dlt[duckdb])
#   Downloading giturlparse-0.12.0-py2.py3-none-any.whl (15 kB)
# Collecting hexbytes>=0.2.2 (from dlt[duckdb])
#   Downloading hexbytes-1.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: humanize>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (4.7.0)
# Collecting jsonpath-ng>=1.5.3 (from dlt[duckdb])
#   Downloading jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Collecting makefun>=1.15.0 (from dlt[duckdb])
#   Downloading makefun-1.15.2-py2.py3-none-any.whl (22 kB)
# Collecting orjson>=3.6.7 (from dlt[duckdb])
#   Downloading orjson-3.9.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.1 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (23.2)
# Collecting pathvalidate>=2.5.2 (from dlt[duckdb])
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting pendulum>=2.1.2 (from dlt[duckdb])
#   Downloading pendulum-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2022.6 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (2023.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (2.31.0)
# Requirement already satisfied: requirements-parser>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (0.5.0)
# Collecting semver>=2.13.0 (from dlt[duckdb])
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools>=65.6.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (67.7.2)
# Collecting simplejson>=3.17.5 (from dlt[duckdb])
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.0.2 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (8.2.3)
# Collecting tomlkit>=0.11.3 (from dlt[duckdb])
#   Downloading tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (4.9.0)
# Collecting tzdata>=2022.1 (from dlt[duckdb])
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: duckdb<0.10.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from dlt[duckdb]) (0.9.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.3->dlt[duckdb]) (0.42.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.3->dlt[duckdb]) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.29->dlt[duckdb])
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# Collecting ply (from jsonpath-ng>=1.5.3->dlt[duckdb])
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.6 in /usr/local/lib/python3.10/dist-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.8.2)
# Collecting time-machine>=2.6.0 (from pendulum>=2.1.2->dlt[duckdb])
#   Downloading time_machine-2.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->dlt[duckdb]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->dlt[duckdb]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->dlt[duckdb]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->dlt[duckdb]) (2024.2.2)
# Requirement already satisfied: types-setuptools>=57.0.0 in /usr/local/lib/python3.10/dist-packages (from requirements-parser>=0.5.0->dlt[duckdb]) (69.0.0.20240125)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.0->dlt[duckdb]) (3.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[duckdb])
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: ply, makefun, tzdata, tomlkit, smmap, simplejson, semver, pathvalidate, orjson, jsonpath-ng, hexbytes, giturlparse, time-machine, gitdb, pendulum, gitpython, dlt
# Successfully installed dlt-0.4.3 gitdb-4.0.11 gitpython-3.1.41 giturlparse-0.12.0 hexbytes-1.0.0 jsonpath-ng-1.6.1 makefun-1.15.2 orjson-3.9.13 pathvalidate-3.2.0 pendulum-3.0.0 ply-3.11 semver-3.0.2 simplejson-3.19.2 smmap-5.0.1 time-machine-2.13.0 tomlkit-0.12.3 tzdata-2023.4

# %%
# !pip list | grep dlt
# Out:
# dlt                              0.4.3

# %%
import dlt
from dlt.sources.helpers import requests
import duckdb
from google.colab import data_table
data_table.enable_dataframe_formatter()

# Specify the URL of the API endpoint
url = "https://api.github.com/repos/dlt-hub/dlt/issues"
# Make a request and check if it was successful
response = requests.get(url)
response.raise_for_status()

pipeline = dlt.pipeline(
    pipeline_name="github_issues",
    destination="duckdb",
    dataset_name="github_data",
)
# The response contains a list of issues
load_info = pipeline.run(response.json(), table_name="issues")

print(load_info)





# a database 'chess_pipeline.duckdb' was created in working directory so just connect to it
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# this lets us query data without adding schema prefix to table names
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")


stats_table = conn.sql("SELECT * FROM issues").df()
display(stats_table)
# Out:
# Pipeline github_issues load step completed in 1.66 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data
# The duckdb destination used duckdb:////content/github_issues.duckdb location to store data
# Load package 1707388704.6721532 is LOADED and contains no failed jobs
# Warning: Total number of columns (71) exceeds max_columns (20). Falling back to pandas display.
#                                                   url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                               repository_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt
# 1   https://api.github.com/repos/dlt-hub/dlt
# 2   https://api.github.com/repos/dlt-hub/dlt
# 3   https://api.github.com/repos/dlt-hub/dlt
# 4   https://api.github.com/repos/dlt-hub/dlt
# 5   https://api.github.com/repos/dlt-hub/dlt
# 6   https://api.github.com/repos/dlt-hub/dlt
# 7   https://api.github.com/repos/dlt-hub/dlt
# 8   https://api.github.com/repos/dlt-hub/dlt
# 9   https://api.github.com/repos/dlt-hub/dlt
# 10  https://api.github.com/repos/dlt-hub/dlt
# 11  https://api.github.com/repos/dlt-hub/dlt
# 12  https://api.github.com/repos/dlt-hub/dlt
# 13  https://api.github.com/repos/dlt-hub/dlt
# 14  https://api.github.com/repos/dlt-hub/dlt
# 15  https://api.github.com/repos/dlt-hub/dlt
# 16  https://api.github.com/repos/dlt-hub/dlt
# 17  https://api.github.com/repos/dlt-hub/dlt
# 18  https://api.github.com/repos/dlt-hub/dlt
# 19  https://api.github.com/repos/dlt-hub/dlt
# 20  https://api.github.com/repos/dlt-hub/dlt
# 21  https://api.github.com/repos/dlt-hub/dlt
# 22  https://api.github.com/repos/dlt-hub/dlt
# 23  https://api.github.com/repos/dlt-hub/dlt
# 24  https://api.github.com/repos/dlt-hub/dlt
# 25  https://api.github.com/repos/dlt-hub/dlt
# 26  https://api.github.com/repos/dlt-hub/dlt
# 27  https://api.github.com/repos/dlt-hub/dlt
# 28  https://api.github.com/repos/dlt-hub/dlt
# 29  https://api.github.com/repos/dlt-hub/dlt
#
#                                            labels_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                            events_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                      html_url          id  \
# 0     https://github.com/dlt-hub/dlt/pull/949  2124229047
# 1   https://github.com/dlt-hub/dlt/issues/947  2123408014
# 2   https://github.com/dlt-hub/dlt/issues/945  2123039607
# 3   https://github.com/dlt-hub/dlt/issues/944  2123033202
# 4   https://github.com/dlt-hub/dlt/issues/943  2122994665
# 5     https://github.com/dlt-hub/dlt/pull/942  2122973566
# 6   https://github.com/dlt-hub/dlt/issues/934  2120650432
# 7   https://github.com/dlt-hub/dlt/issues/933  2118635297
# 8     https://github.com/dlt-hub/dlt/pull/932  2117900219
# 9   https://github.com/dlt-hub/dlt/issues/931  2114822813
# 10  https://github.com/dlt-hub/dlt/issues/930  2114632757
# 11    https://github.com/dlt-hub/dlt/pull/929  2114031010
# 12  https://github.com/dlt-hub/dlt/issues/928  2113950495
# 13  https://github.com/dlt-hub/dlt/issues/925  2111302906
# 14    https://github.com/dlt-hub/dlt/pull/923  2110164616
# 15  https://github.com/dlt-hub/dlt/issues/919  2108171354
# 16  https://github.com/dlt-hub/dlt/issues/899  2086371089
# 17    https://github.com/dlt-hub/dlt/pull/897  2084357058
# 18    https://github.com/dlt-hub/dlt/pull/896  2083657427
# 19    https://github.com/dlt-hub/dlt/pull/891  2079216487
# 20  https://github.com/dlt-hub/dlt/issues/880  2070297949
# 21  https://github.com/dlt-hub/dlt/issues/875  2065770966
# 22  https://github.com/dlt-hub/dlt/issues/873  2062695442
# 23  https://github.com/dlt-hub/dlt/issues/860  2057766820
# 24  https://github.com/dlt-hub/dlt/issues/858  2056675584
# 25  https://github.com/dlt-hub/dlt/issues/855  2054865018
# 26  https://github.com/dlt-hub/dlt/issues/853  2054785168
# 27  https://github.com/dlt-hub/dlt/issues/851  2054324985
# 28    https://github.com/dlt-hub/dlt/pull/837  2046944154
# 29  https://github.com/dlt-hub/dlt/issues/836  2046807741
#
#                 node_id  number  \
# 0   PR_kwDOGvRYu85mU3RJ     949
# 1    I_kwDOGvRYu85-kKKO     947
# 2    I_kwDOGvRYu85-iwN3     945
# 3    I_kwDOGvRYu85-iupy     944
# 4    I_kwDOGvRYu85-ilPp     943
# 5   PR_kwDOGvRYu85mQlpK     942
# 6    I_kwDOGvRYu85-Zo7A     934
# 7    I_kwDOGvRYu85-R88h     933
# 8   PR_kwDOGvRYu85l_RRO     932
# 9    I_kwDOGvRYu85-DaKd     931
# 10   I_kwDOGvRYu85-Crw1     930
# 11  PR_kwDOGvRYu85lyIQe     929
# 12   I_kwDOGvRYu85-AFMf     928
# 13   I_kwDOGvRYu8591-z6     925
# 14  PR_kwDOGvRYu85lkwr2     923
# 15   I_kwDOGvRYu859qCRa     919
# 16   I_kwDOGvRYu858W38R     899
# 17  PR_kwDOGvRYu85kNykk     897
# 18  PR_kwDOGvRYu85kLWdO     896
# 19  PR_kwDOGvRYu85j8fed     891
# 20   I_kwDOGvRYu857Zj1d     880
# 21   I_kwDOGvRYu857ISnW     875
# 22   I_kwDOGvRYu8568jwS     873
# 23   I_kwDOGvRYu856pwek     860
# 24   I_kwDOGvRYu856lmEA     858
# 25   I_kwDOGvRYu856esB6     855
# 26   I_kwDOGvRYu856eYiQ     853
# 27   I_kwDOGvRYu856coL5     851
# 28  PR_kwDOGvRYu85iR16t     837
# 29   I_kwDOGvRYu855_869     836
#
#                                                 title  ...  \
# 0                     Databricks workspace setup docs  ...
# 1     Core extensions to support database replication  ...
# 2   allow to define maximum nesting level per reso...  ...
# 3   Allow to backup and restore pipeline working d...  ...
# 4            use pydata_google_auth in GcpCredentials  ...
# 5                              annotations experiment  ...
# 6    Simplify Parallelization for generator resources  ...
# 7                       Postgres database replication  ...
# 8     feat(filesystem): implement Google Drive source  ...
# 9   Airflow helper: expose internal runner and int...  ...
# 10  Extended filesystem layout placeholders for de...  ...
# 11  Added info about "Rows count" and "Data loadin...  ...
# 12  Warning persists when using `dlt` in local or ...  ...
# 13    Save compressed load files with `.gz` extension  ...
# 14                                    SCD2 Experiment  ...
# 15  Ability to define /configure target schema for...  ...
# 16      Pluggable File Formats including AVRO support  ...
# 17                          Format and lint with Ruff  ...
# 18                             Add some missing tests  ...
# 19                              data sink destination  ...
# 20  Normalize keys for google secrets lookup (or d...  ...
# 21              Finish cleanup of repository env vars  ...
# 22                        Schema management only mode  ...
# 23  `drop_storage()` leaves empty folders dangling...  ...
# 24  [chores] use `dataclass_transform` to autogene...  ...
# 25          create BigQuery adapter for dlt resources  ...
# 26  implement `LoadInfo` and `ExtractInfo` missing...  ...
# 27                             Native Iceberg Support  ...
# 28                         Callback Plugins Framework  ...
# 29  update "Create new destination" how-to to matc...  ...
#
#                               assignee__following_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/f...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/followi...
# 7   https://api.github.com/users/jorritsandbrink/f...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/follow...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/follow...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/follow...
# 21  https://api.github.com/users/sh-rp/following{/...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/followi...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/followi...
#
#                                   assignee__gists_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/g...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/gists{/...
# 7   https://api.github.com/users/jorritsandbrink/g...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/gists{...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/gists{...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/gists{...
# 21  https://api.github.com/users/sh-rp/gists{/gist...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/gists{/...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/gists{/...
#
#                                 assignee__starred_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/s...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/starred...
# 7   https://api.github.com/users/jorritsandbrink/s...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/starre...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/starre...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/starre...
# 21  https://api.github.com/users/sh-rp/starred{/ow...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/starred...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/starred...
#
#                           assignee__subscriptions_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/s...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/subscri...
# 7   https://api.github.com/users/jorritsandbrink/s...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/subscr...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/subscr...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/subscr...
# 21   https://api.github.com/users/sh-rp/subscriptions
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/subscri...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/subscri...
#
#                           assignee__organizations_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/orgs
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6         https://api.github.com/users/steinitzu/orgs
# 7   https://api.github.com/users/jorritsandbrink/orgs
# 8                                                None
# 9                                                None
# 10       https://api.github.com/users/sultaniman/orgs
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17       https://api.github.com/users/sultaniman/orgs
# 18                                               None
# 19                                               None
# 20       https://api.github.com/users/sultaniman/orgs
# 21            https://api.github.com/users/sh-rp/orgs
# 22                                               None
# 23                                               None
# 24                                               None
# 25        https://api.github.com/users/Pipboyguy/orgs
# 26                                               None
# 27                                               None
# 28                                               None
# 29        https://api.github.com/users/steinitzu/orgs
#
#                                   assignee__repos_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/r...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6        https://api.github.com/users/steinitzu/repos
# 7   https://api.github.com/users/jorritsandbrink/r...
# 8                                                None
# 9                                                None
# 10      https://api.github.com/users/sultaniman/repos
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17      https://api.github.com/users/sultaniman/repos
# 18                                               None
# 19                                               None
# 20      https://api.github.com/users/sultaniman/repos
# 21           https://api.github.com/users/sh-rp/repos
# 22                                               None
# 23                                               None
# 24                                               None
# 25       https://api.github.com/users/Pipboyguy/repos
# 26                                               None
# 27                                               None
# 28                                               None
# 29       https://api.github.com/users/steinitzu/repos
#
#                                  assignee__events_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/e...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/events{...
# 7   https://api.github.com/users/jorritsandbrink/e...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/events...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/events...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/events...
# 21  https://api.github.com/users/sh-rp/events{/pri...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/events{...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/events{...
#
#                         assignee__received_events_url assignee__type  \
# 0                                                None           None
# 1   https://api.github.com/users/jorritsandbrink/r...           User
# 2                                                None           None
# 3                                                None           None
# 4                                                None           None
# 5                                                None           None
# 6   https://api.github.com/users/steinitzu/receive...           User
# 7   https://api.github.com/users/jorritsandbrink/r...           User
# 8                                                None           None
# 9                                                None           None
# 10  https://api.github.com/users/sultaniman/receiv...           User
# 11                                               None           None
# 12                                               None           None
# 13                                               None           None
# 14                                               None           None
# 15                                               None           None
# 16                                               None           None
# 17  https://api.github.com/users/sultaniman/receiv...           User
# 18                                               None           None
# 19                                               None           None
# 20  https://api.github.com/users/sultaniman/receiv...           User
# 21  https://api.github.com/users/sh-rp/received_ev...           User
# 22                                               None           None
# 23                                               None           None
# 24                                               None           None
# 25  https://api.github.com/users/Pipboyguy/receive...           User
# 26                                               None           None
# 27                                               None           None
# 28                                               None           None
# 29  https://api.github.com/users/steinitzu/receive...           User
#
#    assignee__site_admin
# 0                   NaN
# 1                 False
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                 False
# 7                 False
# 8                   NaN
# 9                   NaN
# 10                False
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                False
# 18                  NaN
# 19                  NaN
# 20                False
# 21                False
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                False
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                False
#
# [30 rows x 71 columns]

# %%
import dlt
from dlt.sources.helpers import requests
import duckdb
from google.colab import data_table
data_table.enable_dataframe_formatter()

# Specify the URL of the API endpoint
url = "https://api.github.com/repos/dlt-hub/dlt/issues"
# Make a request and check if it was successful
response = requests.get(url)
response.raise_for_status()

pipeline = dlt.pipeline(
    pipeline_name='github_issues',
    destination='duckdb',
    dataset_name='github_data',
)
# The response contains a list of issues
load_info = pipeline.run(
    response.json(),
    table_name="issues",
    write_disposition="replace"  # <-- Add this line
)

print(load_info)




# a database 'chess_pipeline.duckdb' was created in working directory so just connect to it
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# this lets us query data without adding schema prefix to table names
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")


stats_table = conn.sql("SELECT * FROM issues").df()
display(stats_table)
# Out:
# Pipeline github_issues load step completed in 0.70 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data
# The duckdb destination used duckdb:////content/github_issues.duckdb location to store data
# Load package 1707388741.104453 is LOADED and contains no failed jobs
# Warning: Total number of columns (71) exceeds max_columns (20). Falling back to pandas display.
#                                                   url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                               repository_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt
# 1   https://api.github.com/repos/dlt-hub/dlt
# 2   https://api.github.com/repos/dlt-hub/dlt
# 3   https://api.github.com/repos/dlt-hub/dlt
# 4   https://api.github.com/repos/dlt-hub/dlt
# 5   https://api.github.com/repos/dlt-hub/dlt
# 6   https://api.github.com/repos/dlt-hub/dlt
# 7   https://api.github.com/repos/dlt-hub/dlt
# 8   https://api.github.com/repos/dlt-hub/dlt
# 9   https://api.github.com/repos/dlt-hub/dlt
# 10  https://api.github.com/repos/dlt-hub/dlt
# 11  https://api.github.com/repos/dlt-hub/dlt
# 12  https://api.github.com/repos/dlt-hub/dlt
# 13  https://api.github.com/repos/dlt-hub/dlt
# 14  https://api.github.com/repos/dlt-hub/dlt
# 15  https://api.github.com/repos/dlt-hub/dlt
# 16  https://api.github.com/repos/dlt-hub/dlt
# 17  https://api.github.com/repos/dlt-hub/dlt
# 18  https://api.github.com/repos/dlt-hub/dlt
# 19  https://api.github.com/repos/dlt-hub/dlt
# 20  https://api.github.com/repos/dlt-hub/dlt
# 21  https://api.github.com/repos/dlt-hub/dlt
# 22  https://api.github.com/repos/dlt-hub/dlt
# 23  https://api.github.com/repos/dlt-hub/dlt
# 24  https://api.github.com/repos/dlt-hub/dlt
# 25  https://api.github.com/repos/dlt-hub/dlt
# 26  https://api.github.com/repos/dlt-hub/dlt
# 27  https://api.github.com/repos/dlt-hub/dlt
# 28  https://api.github.com/repos/dlt-hub/dlt
# 29  https://api.github.com/repos/dlt-hub/dlt
#
#                                            labels_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                            events_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                      html_url          id  \
# 0     https://github.com/dlt-hub/dlt/pull/949  2124229047
# 1   https://github.com/dlt-hub/dlt/issues/947  2123408014
# 2   https://github.com/dlt-hub/dlt/issues/945  2123039607
# 3   https://github.com/dlt-hub/dlt/issues/944  2123033202
# 4   https://github.com/dlt-hub/dlt/issues/943  2122994665
# 5     https://github.com/dlt-hub/dlt/pull/942  2122973566
# 6   https://github.com/dlt-hub/dlt/issues/934  2120650432
# 7   https://github.com/dlt-hub/dlt/issues/933  2118635297
# 8     https://github.com/dlt-hub/dlt/pull/932  2117900219
# 9   https://github.com/dlt-hub/dlt/issues/931  2114822813
# 10  https://github.com/dlt-hub/dlt/issues/930  2114632757
# 11    https://github.com/dlt-hub/dlt/pull/929  2114031010
# 12  https://github.com/dlt-hub/dlt/issues/928  2113950495
# 13  https://github.com/dlt-hub/dlt/issues/925  2111302906
# 14    https://github.com/dlt-hub/dlt/pull/923  2110164616
# 15  https://github.com/dlt-hub/dlt/issues/919  2108171354
# 16  https://github.com/dlt-hub/dlt/issues/899  2086371089
# 17    https://github.com/dlt-hub/dlt/pull/897  2084357058
# 18    https://github.com/dlt-hub/dlt/pull/896  2083657427
# 19    https://github.com/dlt-hub/dlt/pull/891  2079216487
# 20  https://github.com/dlt-hub/dlt/issues/880  2070297949
# 21  https://github.com/dlt-hub/dlt/issues/875  2065770966
# 22  https://github.com/dlt-hub/dlt/issues/873  2062695442
# 23  https://github.com/dlt-hub/dlt/issues/860  2057766820
# 24  https://github.com/dlt-hub/dlt/issues/858  2056675584
# 25  https://github.com/dlt-hub/dlt/issues/855  2054865018
# 26  https://github.com/dlt-hub/dlt/issues/853  2054785168
# 27  https://github.com/dlt-hub/dlt/issues/851  2054324985
# 28    https://github.com/dlt-hub/dlt/pull/837  2046944154
# 29  https://github.com/dlt-hub/dlt/issues/836  2046807741
#
#                 node_id  number  \
# 0   PR_kwDOGvRYu85mU3RJ     949
# 1    I_kwDOGvRYu85-kKKO     947
# 2    I_kwDOGvRYu85-iwN3     945
# 3    I_kwDOGvRYu85-iupy     944
# 4    I_kwDOGvRYu85-ilPp     943
# 5   PR_kwDOGvRYu85mQlpK     942
# 6    I_kwDOGvRYu85-Zo7A     934
# 7    I_kwDOGvRYu85-R88h     933
# 8   PR_kwDOGvRYu85l_RRO     932
# 9    I_kwDOGvRYu85-DaKd     931
# 10   I_kwDOGvRYu85-Crw1     930
# 11  PR_kwDOGvRYu85lyIQe     929
# 12   I_kwDOGvRYu85-AFMf     928
# 13   I_kwDOGvRYu8591-z6     925
# 14  PR_kwDOGvRYu85lkwr2     923
# 15   I_kwDOGvRYu859qCRa     919
# 16   I_kwDOGvRYu858W38R     899
# 17  PR_kwDOGvRYu85kNykk     897
# 18  PR_kwDOGvRYu85kLWdO     896
# 19  PR_kwDOGvRYu85j8fed     891
# 20   I_kwDOGvRYu857Zj1d     880
# 21   I_kwDOGvRYu857ISnW     875
# 22   I_kwDOGvRYu8568jwS     873
# 23   I_kwDOGvRYu856pwek     860
# 24   I_kwDOGvRYu856lmEA     858
# 25   I_kwDOGvRYu856esB6     855
# 26   I_kwDOGvRYu856eYiQ     853
# 27   I_kwDOGvRYu856coL5     851
# 28  PR_kwDOGvRYu85iR16t     837
# 29   I_kwDOGvRYu855_869     836
#
#                                                 title  ...  \
# 0                     Databricks workspace setup docs  ...
# 1     Core extensions to support database replication  ...
# 2   allow to define maximum nesting level per reso...  ...
# 3   Allow to backup and restore pipeline working d...  ...
# 4            use pydata_google_auth in GcpCredentials  ...
# 5                              annotations experiment  ...
# 6    Simplify Parallelization for generator resources  ...
# 7                       Postgres database replication  ...
# 8     feat(filesystem): implement Google Drive source  ...
# 9   Airflow helper: expose internal runner and int...  ...
# 10  Extended filesystem layout placeholders for de...  ...
# 11  Added info about "Rows count" and "Data loadin...  ...
# 12  Warning persists when using `dlt` in local or ...  ...
# 13    Save compressed load files with `.gz` extension  ...
# 14                                    SCD2 Experiment  ...
# 15  Ability to define /configure target schema for...  ...
# 16      Pluggable File Formats including AVRO support  ...
# 17                          Format and lint with Ruff  ...
# 18                             Add some missing tests  ...
# 19                              data sink destination  ...
# 20  Normalize keys for google secrets lookup (or d...  ...
# 21              Finish cleanup of repository env vars  ...
# 22                        Schema management only mode  ...
# 23  `drop_storage()` leaves empty folders dangling...  ...
# 24  [chores] use `dataclass_transform` to autogene...  ...
# 25          create BigQuery adapter for dlt resources  ...
# 26  implement `LoadInfo` and `ExtractInfo` missing...  ...
# 27                             Native Iceberg Support  ...
# 28                         Callback Plugins Framework  ...
# 29  update "Create new destination" how-to to matc...  ...
#
#                               assignee__following_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/f...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/followi...
# 7   https://api.github.com/users/jorritsandbrink/f...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/follow...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/follow...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/follow...
# 21  https://api.github.com/users/sh-rp/following{/...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/followi...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/followi...
#
#                                   assignee__gists_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/g...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/gists{/...
# 7   https://api.github.com/users/jorritsandbrink/g...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/gists{...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/gists{...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/gists{...
# 21  https://api.github.com/users/sh-rp/gists{/gist...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/gists{/...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/gists{/...
#
#                                 assignee__starred_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/s...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/starred...
# 7   https://api.github.com/users/jorritsandbrink/s...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/starre...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/starre...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/starre...
# 21  https://api.github.com/users/sh-rp/starred{/ow...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/starred...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/starred...
#
#                           assignee__subscriptions_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/s...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/subscri...
# 7   https://api.github.com/users/jorritsandbrink/s...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/subscr...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/subscr...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/subscr...
# 21   https://api.github.com/users/sh-rp/subscriptions
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/subscri...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/subscri...
#
#                           assignee__organizations_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/orgs
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6         https://api.github.com/users/steinitzu/orgs
# 7   https://api.github.com/users/jorritsandbrink/orgs
# 8                                                None
# 9                                                None
# 10       https://api.github.com/users/sultaniman/orgs
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17       https://api.github.com/users/sultaniman/orgs
# 18                                               None
# 19                                               None
# 20       https://api.github.com/users/sultaniman/orgs
# 21            https://api.github.com/users/sh-rp/orgs
# 22                                               None
# 23                                               None
# 24                                               None
# 25        https://api.github.com/users/Pipboyguy/orgs
# 26                                               None
# 27                                               None
# 28                                               None
# 29        https://api.github.com/users/steinitzu/orgs
#
#                                   assignee__repos_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/r...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6        https://api.github.com/users/steinitzu/repos
# 7   https://api.github.com/users/jorritsandbrink/r...
# 8                                                None
# 9                                                None
# 10      https://api.github.com/users/sultaniman/repos
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17      https://api.github.com/users/sultaniman/repos
# 18                                               None
# 19                                               None
# 20      https://api.github.com/users/sultaniman/repos
# 21           https://api.github.com/users/sh-rp/repos
# 22                                               None
# 23                                               None
# 24                                               None
# 25       https://api.github.com/users/Pipboyguy/repos
# 26                                               None
# 27                                               None
# 28                                               None
# 29       https://api.github.com/users/steinitzu/repos
#
#                                  assignee__events_url  \
# 0                                                None
# 1   https://api.github.com/users/jorritsandbrink/e...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6   https://api.github.com/users/steinitzu/events{...
# 7   https://api.github.com/users/jorritsandbrink/e...
# 8                                                None
# 9                                                None
# 10  https://api.github.com/users/sultaniman/events...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17  https://api.github.com/users/sultaniman/events...
# 18                                               None
# 19                                               None
# 20  https://api.github.com/users/sultaniman/events...
# 21  https://api.github.com/users/sh-rp/events{/pri...
# 22                                               None
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/Pipboyguy/events{...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  https://api.github.com/users/steinitzu/events{...
#
#                         assignee__received_events_url assignee__type  \
# 0                                                None           None
# 1   https://api.github.com/users/jorritsandbrink/r...           User
# 2                                                None           None
# 3                                                None           None
# 4                                                None           None
# 5                                                None           None
# 6   https://api.github.com/users/steinitzu/receive...           User
# 7   https://api.github.com/users/jorritsandbrink/r...           User
# 8                                                None           None
# 9                                                None           None
# 10  https://api.github.com/users/sultaniman/receiv...           User
# 11                                               None           None
# 12                                               None           None
# 13                                               None           None
# 14                                               None           None
# 15                                               None           None
# 16                                               None           None
# 17  https://api.github.com/users/sultaniman/receiv...           User
# 18                                               None           None
# 19                                               None           None
# 20  https://api.github.com/users/sultaniman/receiv...           User
# 21  https://api.github.com/users/sh-rp/received_ev...           User
# 22                                               None           None
# 23                                               None           None
# 24                                               None           None
# 25  https://api.github.com/users/Pipboyguy/receive...           User
# 26                                               None           None
# 27                                               None           None
# 28                                               None           None
# 29  https://api.github.com/users/steinitzu/receive...           User
#
#    assignee__site_admin
# 0                   NaN
# 1                 False
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                 False
# 7                 False
# 8                   NaN
# 9                   NaN
# 10                False
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                False
# 18                  NaN
# 19                  NaN
# 20                False
# 21                False
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                False
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                False
#
# [30 rows x 71 columns]

# %%
import dlt
from dlt.sources.helpers import requests

@dlt.resource(table_name="issues", write_disposition="append")
def get_issues(
    created_at=dlt.sources.incremental("created_at", initial_value="1970-01-01T00:00:00Z")
):
    # NOTE: we read only open issues to minimize number of calls to the API.
    # There's a limit of ~50 calls for not authenticated Github users.
    url = (
        "https://api.github.com/repos/dlt-hub/dlt/issues"
        "?per_page=100&sort=created&directions=desc&state=open"
    )

    while True:
        response = requests.get(url)
        response.raise_for_status()
        yield response.json()

        # Stop requesting pages if the last element was already
        # older than initial value
        # Note: incremental will skip those items anyway, we just
        # do not want to use the api limits
        if created_at.start_out_of_range:
            break

        # get next page
        if "next" not in response.links:
            break
        url = response.links["next"]["url"]

pipeline = dlt.pipeline(
    pipeline_name="github_issues_incremental",
    destination="duckdb",
    dataset_name="github_data_append",
)

load_info = pipeline.run(get_issues)
row_counts = pipeline.last_trace.last_normalize_info

print(row_counts)
print("------")
print(load_info)
# Out:
# Normalized data for the following tables:
# - _dlt_pipeline_state: 1 row(s)
# - issues: 87 row(s)
# - issues__labels: 25 row(s)
# - issues__assignees: 29 row(s)
# - issues__performed_via_github_app__events: 25 row(s)
#
# Load package 1707388807.1103961 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
# ------
# Pipeline github_issues_incremental load step completed in 1.33 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data_append
# The duckdb destination used duckdb:////content/github_issues_incremental.duckdb location to store data
# Load package 1707388807.1103961 is LOADED and contains no failed jobs
